# %% [markdown]
# <a href="https://colab.research.google.com/github/maxencebc10/Projet-DATA-groupe-7/blob/main/Biais_Vs_Variance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Quel package utiliser pour le biais vs la variance
# Usuellement on a pandas, numpy matplotlib seaborn et
#scikitlearn
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# !pip install scikit-learn

# %%
#IMPORTS
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import fetch_california_housing

# %%
from sklearn.model_selection import train_test_split, learning_curve
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
